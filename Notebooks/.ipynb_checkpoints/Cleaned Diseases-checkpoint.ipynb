# %%
#importing the packages
import pandas as pd
import numpy as np
import random 

from scipy import misc
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import joblib # for saving algorithm and preprocessing objects
from sklearn.linear_model import LinearRegression

# %%
# uploading the dataset
df = pd.read_csv('RegionalInterestByConditionOverTime.csv')
df.head()
# Out:
#                   dma  geoCode  2004+cancer  2004+cardiovascular  2004+stroke  \
# 0  Portland-Auburn ME      500           44                    6           17
# 1         New York NY      501           47                    6           13
# 2       Binghamton NY      502           48                    3           16
# 3            Macon GA      503           44                   14           14
# 4     Philadelphia PA      504           52                    7           16
#
#    2004+depression  2004+rehab  2004+vaccine  2004+diarrhea  2004+obesity  \
# 0               39          21            31             14            29
# 1               38          16            33             12            27
# 2               50          12            37             24            31
# 3               37          19            49             14            29
# 4               41          23            36             14            30
#
# ...

# %%
print(df.columns)
print(df.shape)
print(df.describe())
# Out:
# Index(['dma', 'geoCode', '2004+cancer', '2004+cardiovascular', '2004+stroke',
#        '2004+depression', '2004+rehab', '2004+vaccine', '2004+diarrhea',
#        '2004+obesity',
#        ...
#        '2016+diabetes', '2017+cancer', '2017+cardiovascular', '2017+stroke',
#        '2017+depression', '2017+rehab', '2017+vaccine', '2017+diarrhea',
#        '2017+obesity', '2017+diabetes'],
#       dtype='object', length=128)
# (210, 128)
#           geoCode  2004+cancer  2004+cardiovascular  2004+stroke  \
# count  210.000000   210.000000           210.000000   210.000000
# mean   641.104762    43.904762             7.433333    17.642857
# std    100.375079     7.618944             7.909647     8.135284
# min    500.000000    27.000000             0.000000     0.000000
# 25%    552.250000    40.000000             5.000000    14.000000
# 50%    627.500000    43.000000             6.000000    16.000000
# 75%    723.500000    47.000000             9.000000    18.000000
# ...

# %%
#IQR range
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# geoCode                171.25
# 2004+cancer              7.00
# 2004+cardiovascular      4.00
# 2004+stroke              4.00
# 2004+depression         14.00
#                         ...
# 2017+rehab              18.00
# 2017+vaccine            12.00
# 2017+diarrhea           11.00
# 2017+obesity            12.75
# 2017+diabetes            8.00
# Length: 127, dtype: float64

# %%
#removing Outliers
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (91, 128)

# %%
global states
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
df['State_Code'] = df['dma'].apply(lambda x: x[x.rfind(" ")+1:])

# %%
df['State'] = df['State_Code'].apply(lambda x:states[x])
df
# Out:
#                                 dma  geoCode  2004+cancer  \
# 0                Portland-Auburn ME      500           44
# 1                       New York NY      501           47
# 4                   Philadelphia PA      504           52
# 5                        Detroit MI      505           47
# 6           Boston MA-Manchester NH      506           48
# ..                              ...      ...          ...
# 202                    San Diego CA      825           42
# 204                    Las Vegas NV      839           33
# 206  Sacramento-Stockton-Modesto CA      862           40
# 208                Chico-Redding CA      868           36
# 209                      Spokane WA      881           44
#
#      2004+cardiovascular  2004+stroke  2004+depression  2004+rehab  \
# 0                      6           17               39          21
# 1                      6           13               38          16
# ...

# %%
df.shape
# Out:
# (91, 130)

# %%
temp_cols = ['cancer','cardiovascular','stroke','depression','rehab','vaccine','diarrhea','obesity','diabetes']
new_columns = ['State','Year',*temp_cols]

# %%
data_final = []
for _, row in df.iterrows():
    keys = list(row.keys())[2:-2]
    values = list(row[2:-2])
    for year in range(0,14):
        d = [row['State'] , year+2003 , *values[year:year+9]]
        data_final.append(d)
dd = pd.DataFrame(data_final , columns = new_columns)
dff = dd.groupby(['State','Year']).mean().reset_index()
dff
# Out:
#          State  Year     cancer  cardiovascular     stroke  depression  \
# 0      Alabama  2003  41.000000        7.000000  18.000000   48.000000
# 1      Alabama  2004   7.000000       18.000000  48.000000   18.000000
# 2      Alabama  2005  18.000000       48.000000  18.000000   29.000000
# 3      Alabama  2006  48.000000       18.000000  29.000000   12.000000
# 4      Alabama  2007  18.000000       29.000000  12.000000   20.000000
# ..         ...   ...        ...             ...        ...         ...
# 569  Wisconsin  2012  63.333333       11.666667  43.000000   12.666667
# 570  Wisconsin  2013  11.666667       43.000000  12.666667   19.333333
# 571  Wisconsin  2014  43.000000       12.666667  19.333333   27.666667
# 572  Wisconsin  2015  12.666667       19.333333  27.666667   22.666667
# 573  Wisconsin  2016  19.333333       27.666667  22.666667   16.000000
#
#          rehab    vaccine   diarrhea    obesity   diabetes
# ...

# %%
dff['Total'] = dff['cancer'] + dff['cardiovascular'] + dff['stroke'] + dff['depression'] + dff['rehab'] + dff['vaccine'] + dff['diarrhea'] + dff['obesity'] + dff['obesity'] 
val_max = dff['Total'].max()
val_min = dff['Total'].min()
dff['Scaled_total'] = dff['Total'].apply(lambda x: (x-val_min)/(val_max-val_min))
dff
# Out:
#          State  Year     cancer  cardiovascular     stroke  depression  \
# 0      Alabama  2003  41.000000        7.000000  18.000000   48.000000
# 1      Alabama  2004   7.000000       18.000000  48.000000   18.000000
# 2      Alabama  2005  18.000000       48.000000  18.000000   29.000000
# 3      Alabama  2006  48.000000       18.000000  29.000000   12.000000
# 4      Alabama  2007  18.000000       29.000000  12.000000   20.000000
# ..         ...   ...        ...             ...        ...         ...
# 569  Wisconsin  2012  63.333333       11.666667  43.000000   12.666667
# 570  Wisconsin  2013  11.666667       43.000000  12.666667   19.333333
# 571  Wisconsin  2014  43.000000       12.666667  19.333333   27.666667
# 572  Wisconsin  2015  12.666667       19.333333  27.666667   22.666667
# 573  Wisconsin  2016  19.333333       27.666667  22.666667   16.000000
#
#          rehab    vaccine   diarrhea    obesity   diabetes       Total  \
# ...

# %%
#normality checkS
from scipy import stats
stats.shapiro(dff['cancer'])
# Out:
# (0.9429472088813782, 4.765833588231752e-14)

# %%
dff[dff["State"]=='Missouri']['rehab'].plot(kind='density', subplots=True, layout=(1, 2), 
                  sharex=False, figsize=(10, 4));

# %%
dff['cancer'].plot.hist()

# %%
plt.scatter(dff[dff['State']=='Missouri']['Year'], dff[dff['State']=='Missouri']['rehab']);

# %%
# grouped dataset
dffGroup = dff.groupby(['State', 'Year']).mean().reset_index()
dffGroup.shape
# Out:
# (574, 13)

# %%
dffGroup.describe()
# Out:
#               Year      cancer  cardiovascular      stroke  depression  \
# count   574.000000  574.000000      574.000000  574.000000  574.000000
# mean   2009.500000   28.006214       26.910366   28.143525   28.344599
# std       4.034645   16.025595       15.490177   14.513322   14.391763
# min    2003.000000    4.000000        4.000000    6.000000    6.000000
# 25%    2006.000000   14.333333       14.333333   16.000000   16.000000
# 50%    2009.500000   25.416667       24.000000   25.166667   25.333333
# 75%    2013.000000   40.000000       37.000000   37.250000   37.250000
# max    2016.000000   77.000000       77.000000   77.000000   77.000000
#
#             rehab     vaccine    diarrhea     obesity    diabetes       Total  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean    26.946138   29.136556   28.266696   28.923868   28.314605  253.601829
# std     13.867868   14.599570   14.783249   14.338531   14.330115   35.118794
# ...

# %%
plt.scatter(dffGroup[dffGroup['State']=='Missouri']['Year'], dffGroup[dffGroup['State']=='Missouri']['cancer']);

# %%
joblib.dump(dffGroup, "./processed_data2.joblib", compress=True)
# Out:
# ['./processed_data2.joblib']

# %%
testing_Data = joblib.load("./processed_data2.joblib")

# %%
from sklearn.linear_model import LinearRegression

def state_data(state, data, dff):
    t = dff[dff['State']==state].sort_values(by='Year')
    
    clf = LinearRegression()
    clf.fit(t[['Year']], t[data])
    years = np.arange(2017, 2025, 1)
    tt = pd.DataFrame({'Year': years, data: clf.predict(years.reshape(-1, 1))})
    
    pd.concat([t, tt], sort=False).set_index('Year')[data].plot(color='red')
    t.set_index('Year')[data].plot(figsize=(15, 5), xticks=(np.arange(2000, 2020, 1)))
    
    return print(clf.predict(years.reshape(-1, 1)))

# %%
state_data('Missouri', 'cancer', testing_Data)
# Out:
# [30.24542125 30.47179487 30.6981685  30.92454212 31.15091575 31.37728938
#  31.603663   31.83003663]
